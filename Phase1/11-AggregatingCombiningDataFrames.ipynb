# %% [markdown]
# # Aggregating and Combining `pandas` DataFrames

# %% [markdown]
# ## Objectives

# %% [markdown]
# - Use GroupBy objects to organize and aggregate data
# - Create pivot tables from DataFrames
# - Combine DataFrames by merging, joining, and concatinating

# %% [markdown]
# ## Set Up

# %% [markdown]
# Surprise, surprise... we're still working with the Austin Animal Center Data! Let's start with Outcomes

# %%
# Imports

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
# Read in our outcomes data
# Use the parse_dates argument to parse DateTime and Date of Birth
outcomes = pd.read_csv('data/Austin_Animal_Center_Outcomes_053122.csv',
                      parse_dates=['DateTime', 'Date of Birth'])

# %%
# Check it out
outcomes.head()
# Out:
#   Animal ID   Name            DateTime MonthYear Date of Birth Outcome Type  \
# 0   A794011  Chunk 2019-05-08 18:20:00  May 2019    2017-05-02    Rto-Adopt
# 1   A776359  Gizmo 2018-07-18 16:02:00  Jul 2018    2017-07-12     Adoption
# 2   A821648    NaN 2020-08-16 11:38:00  Aug 2020    2019-08-16   Euthanasia
# 3   A720371  Moose 2016-02-13 17:59:00  Feb 2016    2015-10-08     Adoption
# 4   A674754    NaN 2014-03-18 11:47:00  Mar 2014    2014-03-12     Transfer
#
#   Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0             NaN         Cat    Neutered Male          2 years
# 1             NaN         Dog    Neutered Male           1 year
# 2             NaN       Other          Unknown           1 year
# 3             NaN         Dog    Neutered Male         4 months
# 4         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color
# 0              Domestic Shorthair Mix  Brown Tabby/White
# 1             Chihuahua Shorthair Mix        White/Brown
# 2                             Raccoon               Gray
# 3  Anatol Shepherd/Labrador Retriever               Buff
# 4              Domestic Shorthair Mix       Orange Tabby

# %%
# Check the info
outcomes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139957 entries, 0 to 139956
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Animal ID         139957 non-null  object
#  1   Name              98510 non-null   object
#  2   DateTime          139957 non-null  datetime64[ns]
#  3   MonthYear         139957 non-null  object
#  4   Date of Birth     139957 non-null  datetime64[ns]
#  5   Outcome Type      139934 non-null  object
#  6   Outcome Subtype   64116 non-null   object
#  7   Animal Type       139957 non-null  object
#  8   Sex upon Outcome  139956 non-null  object
#  9   Age upon Outcome  139936 non-null  object
#  10  Breed             139957 non-null  object
#  11  Color             139957 non-null  object
# dtypes: datetime64[ns](2), object(10)
# memory usage: 12.8+ MB

# %%
# Let's create our Age in Days column
outcomes['Calculated Age in Days'] = pd.to_datetime(outcomes['DateTime'].dt.date) - outcomes['Date of Birth']

# %%
# Grab just the integer here...
outcomes['Calculated Age in Days'] = outcomes['Calculated Age in Days'].dt.days

# %%
# Sanity check
outcomes.head()
# Out:
#   Animal ID   Name            DateTime MonthYear Date of Birth Outcome Type  \
# 0   A794011  Chunk 2019-05-08 18:20:00  May 2019    2017-05-02    Rto-Adopt
# 1   A776359  Gizmo 2018-07-18 16:02:00  Jul 2018    2017-07-12     Adoption
# 2   A821648    NaN 2020-08-16 11:38:00  Aug 2020    2019-08-16   Euthanasia
# 3   A720371  Moose 2016-02-13 17:59:00  Feb 2016    2015-10-08     Adoption
# 4   A674754    NaN 2014-03-18 11:47:00  Mar 2014    2014-03-12     Transfer
#
#   Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0             NaN         Cat    Neutered Male          2 years
# 1             NaN         Dog    Neutered Male           1 year
# 2             NaN       Other          Unknown           1 year
# 3             NaN         Dog    Neutered Male         4 months
# 4         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color  \
# 0              Domestic Shorthair Mix  Brown Tabby/White
# 1             Chihuahua Shorthair Mix        White/Brown
# 2                             Raccoon               Gray
# 3  Anatol Shepherd/Labrador Retriever               Buff
# 4              Domestic Shorthair Mix       Orange Tabby
#
#    Calculated Age in Days
# 0                     736
# 1                     371
# 2                     366
# 3                     128
# 4                       6

# %% [markdown]
# ## Aggregating over DataFrames: `.groupby()`

# %% [markdown]
# Those of you familiar with SQL have probably used the GROUP BY command. (And if you haven't, you'll see it very soon!) Pandas has this, too.
#
# The `.groupby()` method is especially useful for aggregate functions applied to the data grouped in particular ways.

# %%
# Just using groupby outputs some weird GroupBy object... not helpful
outcomes.groupby(by=['Animal Type']).count()
# Out:
#              Animal ID   Name  DateTime  MonthYear  Date of Birth  \
# Animal Type
# Bird               664    147       664        664            664
# Cat              53092  31197     53092      53092          53092
# Dog              78736  66044     78736      78736          78736
# Livestock           25      3        25         25             25
# Other             7440   1119      7440       7440           7440
#
#              Outcome Type  Outcome Subtype  Sex upon Outcome  \
# Animal Type
# Bird                  664              384               664
# Cat                 53088            32388             53092
# Dog                 78722            25316             78735
# Livestock              25               19                25
# Other                7435             6009              7440
#
#              Age upon Outcome  Breed  Color  Calculated Age in Days
# Animal Type
# Bird                      664    664    664                     664
# Cat                     53091  53092  53092                   53092
# Dog                     78731  78736  78736                   78736
# Livestock                  25     25     25                      25
# Other                    7425   7440   7440                    7440

# %% [markdown]
# Once we know we are working with a type of object, it opens up a suite of attributes and methods. One attribute we can look at is `groups`.

# %%
# This returns each group indexed by the group name, e.g. 'Bird',
# along with the row indices of each value
outcomes.groupby('Animal Type').groups.keys()
# Out:
# dict_keys(['Bird', 'Cat', 'Dog', 'Livestock', 'Other'])

# %%
# Same goes for multi-index groupbys
outcomes.groupby(['Animal Type', 'Sex upon Outcome']).groups
# Out:
# {('Cat', 'Neutered Male'): [0, 7, 8, 11, 26, 56, 67, 70, 75, 78, 80, 83, 89, 90, 92, 94, 97, 120, 139, 151, 158, 164, 191, 194, 200, 203, 227, 257, 266, 273, 274, 275, 288, 297, 307, 317, 324, 325, 364, 372, 373, 381, 418, 420, 449, 460, 462, 466, 497, 507, 508, 526, 532, 544, 555, 559, 569, 575, 578, 585, 589, 597, 603, 617, 618, 620, 644, 646, 656, 660, 664, 665, 666, 673, 683, 687, 692, 699, 701, 703, 714, 722, 727, 728, 739, 747, 751, 760, 763, 775, 787, 797, 799, 817, 827, 828, 831, 834, 841, 842, ...], ('Dog', 'Neutered Male'): [1, 3, 6, 21, 28, 29, 31, 32, 35, 36, 38, 39, 46, 47, 50, 51, 52, 57, 58, 59, 60, 62, 64, 74, 76, 81, 82, 85, 86, 88, 99, 100, 106, 107, 109, 114, 127, 130, 132, 134, 136, 137, 143, 144, 149, 159, 163, 166, 169, 173, 174, 180, 183, 186, 188, 195, 197, 199, 201, 211, 218, 220, 221, 222, 229, 231, 233, 236, 242, 249, 250, 253, 256, 264, 269, 270, 276, 286, 289, 292, 301, 305, 313, 315, 316, 326, 329, 332, 334, 339, 342, 345, 346, 347, 348, 349, 353, 356, 368, 370, ...], ('Other', 'Unknown'): [2, 19, 27, 33, 40, 53, 71, 72, 77, 103, 150, 172, 185, 235, 243, 263, 280, 298, 344, 406, 412, 422, 479, 505, 543, 579, 580, 604, 607, 632, 637, 710, 716, 724, 735, 810, 837, 840, 859, 865, 884, 894, 924, 947, 1065, 1066, 1072, 1090, 1186, 1193, 1201, 1236, 1243, 1280, 1306, 1346, 1361, 1407, 1418, 1450, 1461, 1470, 1473, 1506, 1557, 1592, 1626, 1660, 1673, 1688, 1692, 1745, 1760, 1774, 1803, 1810, 1833, 1844, 1848, 1854, 1883, 1908, 1924, 1934, 1952, 2035, 2038, 2066, 2067, 2078, 2103, 2185, 2200, 2210, 2271, 2312, 2400, 2402, 2420, 2456, ...], ('Cat', 'Intact Male'): [4, 14, 15, 17, 37, 66, 68, 95, 113, 116, 118, 157, 170, 192, 219, 278, 281, 291, 318, 337, 350, 366, 367, 379, 384, 390, 398, 425, 437, 444, 490, 556, 605, 634, 638, 639, 661, 672, 681, 685, 709, 712, 771, 777, 820, 835, 863, 875, 882, 885, 887, 909, 928, 943, 959, 962, 975, 989, 990, 1007, 1013, 1022, 1043, 1046, 1051, 1057, 1068, 1069, 1089, 1093, 1094, 1097, 1168, 1171, 1192, 1194, 1195, 1196, 1202, 1231, 1238, 1249, 1305, 1309, 1314, 1328, 1329, 1362, 1373, 1379, 1417, 1423, 1452, 1513, 1517, 1535, 1563, 1566, 1585, 1591, ...], ('Dog', 'Spayed Female'): [5, 9, 23, 25, 30, 41, 42, 43, 45, 48, 55, 61, 63, 69, 79, 91, 93, 96, 104, 108, 110, 111, 119, 125, 128, 129, 133, 135, 138, 140, 153, 155, 161, 162, 165, 179, 182, 190, 193, 198, 204, 210, 213, 214, 216, 225, 228, 234, 237, 241, 244, 247, 252, 258, 260, 262, 265, 272, 277, 283, 293, 308, 309, 310, 311, 312, 319, 321, 330, 336, 341, 343, 354, 355, 357, 360, 389, 393, 394, 395, 401, 402, 407, 408, 414, 431, 436, 442, 445, 452, 453, 456, 459, 464, 467, 480, 487, 503, 506, 512, ...], ('Cat', 'Intact Female'): [10, 18, 24, 115, 117, 122, 141, 171, 176, 202, 212, 245, 255, 261, 285, 306, 320, 340, 359, 385, 416, 447, 458, 486, 501, 502, 515, 520, 527, 584, 586, 606, 609, 615, 648, 651, 694, 719, 731, 741, 762, 769, 798, 800, 830, 845, 848, 853, 856, 880, 895, 899, 935, 951, 964, 973, 999, 1008, 1020, 1047, 1056, 1064, 1081, 1082, 1101, 1102, 1104, 1112, 1131, 1141, 1154, 1162, 1166, 1178, 1180, 1219, 1221, 1227, 1255, 1265, 1296, 1297, 1301, 1304, 1317, 1323, 1357, 1374, 1384, 1413, 1439, 1442, 1484, 1492, 1499, 1501, 1521, 1564, 1598, 1640, ...], ('Dog', 'Intact Female'): [12, 13, 73, 112, 121, 123, 146, 154, 160, 181, 187, 189, 208, 248, 259, 287, 295, 296, 300, 322, 377, 391, 404, 415, 417, 419, 441, 446, 473, 485, 489, 494, 495, 518, 524, 538, 562, 587, 590, 594, 635, 655, 691, 696, 698, 705, 745, 746, 756, 759, 791, 793, 857, 864, 890, 900, 905, 982, 987, 1024, 1053, 1074, 1092, 1099, 1113, 1150, 1175, 1176, 1177, 1203, 1278, 1290, 1318, 1326, 1327, 1332, 1338, 1345, 1385, 1409, 1411, 1415, 1427, 1430, 1466, 1474, 1476, 1485, 1533, 1552, 1553, 1555, 1562, 1602, 1609, 1615, 1627, 1630, 1636, 1655, ...], ('Cat', 'Spayed Female'): [16, 20, 54, 84, 98, 102, 142, 147, 148, 152, 156, 167, 178, 184, 207, 209, 223, 230, 238, 240, 246, 251, 267, 268, 279, 282, 290, 294, 299, 302, 304, 323, 327, 328,  ...

# %%
# .groups outputs a dictionary, so we can access the group names using keys()
outcomes.groupby(['Animal Type', 'Sex upon Outcome']).groups.keys()
# Out:
# dict_keys([('Cat', 'Neutered Male'), ('Dog', 'Neutered Male'), ('Other', 'Unknown'), ('Cat', 'Intact Male'), ('Dog', 'Spayed Female'), ('Cat', 'Intact Female'), ('Dog', 'Intact Female'), ('Cat', 'Spayed Female'), ('Dog', 'Intact Male'), ('Cat', 'Unknown'), ('Other', 'Spayed Female'), ('Other', 'Intact Male'), ('Bird', 'Intact Male'), ('Dog', 'Unknown'), ('Other', 'Intact Female'), ('Other', 'Neutered Male'), ('Bird', 'Unknown'), ('Bird', 'Intact Female'), ('Livestock', 'Intact Female'), ('Livestock', 'Unknown'), ('Livestock', 'Neutered Male'), ('Livestock', 'Intact Male'), ('Dog', nan)])

# %%
# We can then get a specific group, such as cats that were adopted
outcomes.groupby(['Animal Type', 'Sex upon Outcome']).get_group(('Dog', 'Intact Female'))
# Out:
#        Animal ID     Name            DateTime MonthYear Date of Birth  \
# 12       A818049    Fiona 2020-06-01 13:24:00  Jun 2020    2018-06-01
# 13       A843327    *Mary 2021-10-08 13:25:00  Oct 2021    2019-09-29
# 73       A781976   *Fancy 2018-10-16 14:25:00  Oct 2018    2017-10-08
# 112      A769199   Sophia 2018-04-03 16:33:00  Apr 2018    2016-04-01
# 121      A808447     Elle 2019-12-04 14:45:00  Dec 2019    2019-05-08
# ...          ...      ...                 ...       ...           ...
# 139861   A858077  A858077 2022-05-27 13:29:00  May 2022    2020-05-25
# 139862   A858195      NaN 2022-05-26 13:35:00  May 2022    2022-05-05
# 139871   A858275     Kira 2022-05-27 14:27:00  May 2022    2021-05-27
# 139891   A858008      NaN 2022-05-24 13:06:00  May 2022    2019-05-24
# 139938   A858098  A858098 2022-05-27 11:16:00  May 2022    2017-05-25
#
#            Outcome Type Outcome Subtype Animal Type Sex upon Outcome  \
# 12      Return to Owner             NaN         Dog    Intact Female
# 13             Transfer       Out State         Dog    Intact Female
# 73             Transfer         Partner         Dog    Intact Female
# 112     Return to Owner             NaN         Dog    Intact Female
# 121            Adoption             NaN         Dog    Intact Female
# ...                 ...             ...         ...              ...
# 139861  Return to Owner             NaN         Dog    Intact Female
# 139862         Transfer         Partner         Dog    Intact Female
# 139871  Return to Owner             NaN         Dog    Intact Female
# 139891         Transfer         Partner         Dog    Intact Female
# 139938         Transfer         Partner         Dog    Intact Female
#
#        Age upon Outcome                    Breed            Color  \
# 12              2 years                 Pit Bull       White/Blue
# 13              2 years  Chihuahua Shorthair Mix      Black/White
# 73               1 year      German Shepherd Mix            White
# 112             2 years            Dachshund Mix        Black/Tan
# 121            6 months       Labrador Retriever            Black
# ...                 ...                      ...              ...
# 139861          2 years                 Pit Bull        Brown/Tan
# 139862          3 weeks                 Pit Bull  Chocolate/White
# 139871           1 year            Alaskan Husky      Black/White
# 139891          3 years                      Pug              Tan
# 139938          5 years                 Shih Tzu      Black/White
#
#         Calculated Age in Days
# 12                         731
# 13                         740
# 73                         373
# 112                        732
# 121                        210
# ...                        ...
# 139861                     732
# 139862                      21
# 139871                     365
# 139891                    1096
# 139938                    1828
#
# [8149 rows x 13 columns]

# %% [markdown]
# ## Aggregating

# %% [markdown]
# Once again, as we will see in SQL, groupby objects are intended to be used with aggregation. In SQL, we will see that our queries that include GROUP BY require aggregation performed on columns.
#
# We can use `.sum()`, `.mean()`, `.count()`, `.max()`, `.min()`, etc. Find a list of common aggregations [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html).

# %%
# Try using count
outcomes.groupby('Animal Type')['Calculated Age in Days'].agg(['mean', 'median'])
# Out:
#                     mean  median
# Animal Type
# Bird          538.016566   373.5
# Cat           532.792831   111.0
# Dog          1000.154567   730.0
# Livestock     503.800000   383.0
# Other         483.761290   366.0

# %% [markdown]
# ## Exercise

# %% [markdown]
# Use `.groupby()` to find the most recent birth date of each (main) animal type.

# %%
# Your code here
outcomes.groupby('Animal Type')[['Date of Birth']].max()
# Out:
#             Date of Birth
# Animal Type
# Bird           2022-03-24
# Cat            2022-05-28
# Dog            2022-05-05
# Livestock      2020-05-28
# Other          2022-04-06

# %% [markdown]
# # Pivoting a DataFrame

# %% [markdown]
# ## `.pivot_table()`

# %% [markdown]
# Those of you familiar with Excel have probably used Pivot Tables. Pandas has a similar functionality.
#
# Grouping by two different columns can be very helpful.

# %%
# Group by Outcome Type and Sex upon Outcome
outcomes.groupby(['Outcome Type', 'Sex upon Outcome']).mean()
# Out:
#                                   Calculated Age in Days
# Outcome Type    Sex upon Outcome
# Adoption        Intact Female                 420.980477
#                 Intact Male                   475.007550
#                 Neutered Male                 650.555269
#                 Spayed Female                 646.295841
#                 Unknown                       386.297980
# Died            Intact Female                 348.707831
#                 Intact Male                   301.036145
#                 Neutered Male                1842.490385
#                 Spayed Female                2091.836735
#                 Unknown                       312.623626
# Disposal        Intact Female                 416.108108
#                 Intact Male                   725.140625
#                 Neutered Male                1987.777778
#                 Spayed Female                2470.166667
#                 Unknown                       449.214700
# Euthanasia      Intact Female                1125.071558
#                 Intact Male                   917.067214
#                 Neutered Male                2235.501742
#                 Spayed Female                2317.935185
#                 Unknown                       506.181462
# Missing         Intact Female                 266.800000
#                 Intact Male                   340.846154
#                 Neutered Male                1188.285714
#                 Spayed Female                1262.733333
#                 Unknown                       169.250000
# Relocate        Intact Female                 732.000000
#                 Neutered Male                1105.000000
#                 Spayed Female                 495.000000
#                 Unknown                       588.761905
# Return to Owner Intact Female                1064.451399
#                 Intact Male                  1106.558726
#                 Neutered Male                1636.608068
#                 Spayed Female                1753.323775
#                 Unknown                       769.424731
# Rto-Adopt       Intact Female                1455.724138
#                 Intact Male                  1484.439024
#                 Neutered Male                1249.344196
#                 Spayed Female                1241.921450
#                 Unknown                      1590.000000
# Transfer        Intact Female                 407.642697
#                 Intact Male                   351.665780
#                 Neutered Male                1124.760147
#                 Spayed Female                1097.225019
#                 Unknown                       171.231835

# %% [markdown]
# But it has the unsavory side effect of creating a two-level index. This can be a good time to use `.pivot_table()`.
#
# (There is also a `.pivot()`. For the somewhat subtle differences, see [here](https://stackoverflow.com/questions/30960338/pandas-difference-between-pivot-and-pivot-table-why-is-only-pivot-table-workin).)

# %%
# Check it out!
outcomes.pivot_table(index='Outcome Type', columns='Sex upon Outcome', aggfunc='mean')
# Out:
#                  Calculated Age in Days                             \
# Sex upon Outcome          Intact Female  Intact Male Neutered Male
# Outcome Type
# Adoption                     420.980477   475.007550    650.555269
# Died                         348.707831   301.036145   1842.490385
# Disposal                     416.108108   725.140625   1987.777778
# Euthanasia                  1125.071558   917.067214   2235.501742
# Missing                      266.800000   340.846154   1188.285714
# Relocate                     732.000000          NaN   1105.000000
# Return to Owner             1064.451399  1106.558726   1636.608068
# Rto-Adopt                   1455.724138  1484.439024   1249.344196
# Transfer                     407.642697   351.665780   1124.760147
#
#
# Sex upon Outcome Spayed Female      Unknown
# Outcome Type
# Adoption            646.295841   386.297980
# Died               2091.836735   312.623626
# Disposal           2470.166667   449.214700
# Euthanasia         2317.935185   506.181462
# Missing            1262.733333   169.250000
# Relocate            495.000000   588.761905
# Return to Owner    1753.323775   769.424731
# Rto-Adopt          1241.921450  1590.000000
# Transfer           1097.225019   171.231835

# %% [markdown]
# # Methods for Combining DataFrames: `.join()`, `.merge()`, `.concat()`
#
# Many ways to combine dataframes! Luckily, pandas has great docs: https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html

# %% [markdown]
# ## `.join()`

# %%
toy1 = pd.DataFrame([[63, 142], [33, 47]], columns=['age', 'HP'])
toy2 = pd.DataFrame([[63, 100], [33, 200]], columns=['age', 'MP'])

toy1
# Out:
#    age   HP
# 0   63  142
# 1   33   47

# %%
toy2
# Out:
#    age   MP
# 0   63  100
# 1   33  200

# %%
# We can't just join these as they are, since we haven't specified our suffixes

toy1.join(toy2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-ab3e8f36fbb5> in <module>
#       1 # We can't just join these as they are, since we haven't specified our suffixes
#       2
# ----> 3 toy1.join(toy2)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7868         5  K5  A5  NaN
#    7869         """
# -> 7870         return self._join_compat(
#    7871             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7872         )
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7884
#    7885         if isinstance(other, DataFrame):
# -> 7886             return merge(
#    7887                 self,
#    7888                 other,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ---> 89     return op.get_result()
#      90
#      91
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#     668         join_index, left_indexer, right_indexer = self._get_join_info()
#     669
# --> 670         llabels, rlabels = _items_overlap_with_suffix(
#     671             self.left._info_axis, self.right._info_axis, self.suffixes
#     672         )
#
# ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\reshape\merge.py in _items_overlap_with_suffix(left, right, suffixes)
#    2089
#    2090     if not lsuffix and not rsuffix:
# -> 2091         raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2092
#    2093     def renamer(x, suffix):
#
# ValueError: columns overlap but no suffix specified: Index(['age'], dtype='object')

# %%
toy1.join(toy2, lsuffix='1', rsuffix='2')
# Out:
#    age1   HP  age2   MP
# 0    63  142    63  100
# 1    33   47    33  200

# %% [markdown]
# If we don't want to keep both, we could set the overlapping column as the index in each DataFrame:

# %%
toy1.set_index('age').join(toy2.set_index('age'))
# Out:
#       HP   MP
# age
# 63   142  100
# 33    47  200

# %%
toy1.drop('age', axis=1).join(toy2)
# Out:
#     HP  age   MP
# 0  142   63  100
# 1   47   33  200

# %% [markdown]
# ## `.merge()`

# %% [markdown]
# Or we could use `.merge()`:

# %%
toy1.merge(toy2)
# Out:
#    age   HP   MP
# 0   63  142  100
# 1   33   47  200

# %%
ds_chars = pd.read_csv('data/ds_chars.csv', index_col=0)
ds_chars
# Out:
#      name   HP home_state
# 0    greg  200         WA
# 1   miles  200         WA
# 2    alan  170         TX
# 3  alison  300         DC
# 4  rachel  200         TX

# %%
states = pd.read_csv('data/states.csv', index_col=0)
states
# Out:
#   state   nickname     capital
# 0    WA  evergreen     Olympia
# 1    TX      alamo      Austin
# 2    DC   district  Washington
# 3    OH    buckeye    Columbus
# 4    OR     beaver       Salem

# %% [markdown]
# ## The `how` Parameter

# %% [markdown]
# This parameter in both `.join()` and `.merge()` tells the compiler what sort of join to effect. We'll cover this in detail when we discuss SQL.
#
# ![image showcasing how the how parameter in a join/merge would combine the two datasets, using venn-style diagrams](https://www.datasciencemadesimple.com/wp-content/uploads/2017/09/join-or-merge-in-python-pandas-1.png)
# [[Image Source]](https://www.datasciencemadesimple.com/join-merge-data-frames-pandas-python/)

# %%
ds_chars.merge(states,
               left_on='home_state',
               right_on='state',
               how='inner')
# Out:
#      name   HP home_state state   nickname     capital
# 0    greg  200         WA    WA  evergreen     Olympia
# 1   miles  200         WA    WA  evergreen     Olympia
# 2    alan  170         TX    TX      alamo      Austin
# 3  rachel  200         TX    TX      alamo      Austin
# 4  alison  300         DC    DC   district  Washington

# %%
ds_chars.merge(states,
               left_on='home_state',
               right_on='state',
               how='outer')
# Out:
#      name     HP home_state state   nickname     capital
# 0    greg  200.0         WA    WA  evergreen     Olympia
# 1   miles  200.0         WA    WA  evergreen     Olympia
# 2    alan  170.0         TX    TX      alamo      Austin
# 3  rachel  200.0         TX    TX      alamo      Austin
# 4  alison  300.0         DC    DC   district  Washington
# 5     NaN    NaN        NaN    OH    buckeye    Columbus
# 6     NaN    NaN        NaN    OR     beaver       Salem

# %% [markdown]
# ## `pd.concat()`

# %% [markdown]
# This method takes a *list* of pandas objects as arguments.

# %%
prefs = pd.read_csv('data/preferences.csv', index_col=0)
prefs
# Out:
#     cuisine        genre
# 0     Greek       horror
# 1    Indian        scifi
# 2  American      fantasy
# 3      Thai         tech
# 4    Indian  documentary

# %%
ds_full = pd.concat([ds_chars, prefs])
ds_full
# Out:
#      name     HP home_state   cuisine        genre
# 0    greg  200.0         WA       NaN          NaN
# 1   miles  200.0         WA       NaN          NaN
# 2    alan  170.0         TX       NaN          NaN
# 3  alison  300.0         DC       NaN          NaN
# 4  rachel  200.0         TX       NaN          NaN
# 0     NaN    NaN        NaN     Greek       horror
# 1     NaN    NaN        NaN    Indian        scifi
# 2     NaN    NaN        NaN  American      fantasy
# 3     NaN    NaN        NaN      Thai         tech
# 4     NaN    NaN        NaN    Indian  documentary

# %% [markdown]
# `pd.concat()`–– and many other pandas operations –– make use of an `axis` parameter. For this particular method I need to specify whether I want to concatenate the DataFrames *row-wise* (`axis=0`) or *column-wise* (`axis=1`). The default is `axis=0`, so let's override that!

# %%
ds_full = pd.concat([ds_chars, prefs], axis=1)
ds_full

# %% [markdown]
# ## Back to the Center
#
# We have Intakes data and we have Outcomes data... time to merge!

# %%
# Peek at the outcomes data we already had in here
outcomes.head()
# Out:
#   Animal ID   Name            DateTime MonthYear Date of Birth Outcome Type  \
# 0   A794011  Chunk 2019-05-08 18:20:00  May 2019    2017-05-02    Rto-Adopt
# 1   A776359  Gizmo 2018-07-18 16:02:00  Jul 2018    2017-07-12     Adoption
# 2   A821648    NaN 2020-08-16 11:38:00  Aug 2020    2019-08-16   Euthanasia
# 3   A720371  Moose 2016-02-13 17:59:00  Feb 2016    2015-10-08     Adoption
# 4   A674754    NaN 2014-03-18 11:47:00  Mar 2014    2014-03-12     Transfer
#
#   Outcome Subtype Animal Type Sex upon Outcome Age upon Outcome  \
# 0             NaN         Cat    Neutered Male          2 years
# 1             NaN         Dog    Neutered Male           1 year
# 2             NaN       Other          Unknown           1 year
# 3             NaN         Dog    Neutered Male         4 months
# 4         Partner         Cat      Intact Male           6 days
#
#                                 Breed              Color  \
# 0              Domestic Shorthair Mix  Brown Tabby/White
# 1             Chihuahua Shorthair Mix        White/Brown
# 2                             Raccoon               Gray
# 3  Anatol Shepherd/Labrador Retriever               Buff
# 4              Domestic Shorthair Mix       Orange Tabby
#
#    Calculated Age in Days
# 0                     736
# 1                     371
# 2                     366
# 3                     128
# 4                       6

# %%
# Read in the intakes data
# We can parse our dates again, if we want
intakes = pd.read_csv('data/Austin_Animal_Center_Intakes_053122.csv')
# Check it out
intakes.head()
# Out:
#   Animal ID     Name                DateTime     MonthYear  \
# 0   A786884   *Brock  01/03/2019 04:19:00 PM  January 2019
# 1   A706918    Belle  07/05/2015 12:59:00 PM     July 2015
# 2   A724273  Runster  04/14/2016 06:43:00 PM    April 2016
# 3   A665644      NaN  10/21/2013 07:59:00 AM  October 2013
# 4   A682524      Rio  06/29/2014 10:38:00 AM     June 2014
#
#                         Found Location Intake Type Intake Condition  \
# 0  2501 Magin Meadow Dr in Austin (TX)       Stray           Normal
# 1     9409 Bluegrass Dr in Austin (TX)       Stray           Normal
# 2   2818 Palomino Trail in Austin (TX)       Stray           Normal
# 3                          Austin (TX)       Stray             Sick
# 4        800 Grove Blvd in Austin (TX)       Stray           Normal
#
#   Animal Type Sex upon Intake Age upon Intake  \
# 0         Dog   Neutered Male         2 years
# 1         Dog   Spayed Female         8 years
# 2         Dog     Intact Male       11 months
# 3         Cat   Intact Female         4 weeks
# 4         Dog   Neutered Male         4 years
#
#                                    Breed        Color
# 0                             Beagle Mix     Tricolor
# 1               English Springer Spaniel  White/Liver
# 2                            Basenji Mix  Sable/White
# 3                 Domestic Shorthair Mix       Calico
# 4  Doberman Pinsch/Australian Cattle Dog     Tan/Gray

# %%
# Let's try merging on Animal ID
combined = outcomes.merge(intakes, 
                          how='inner', 
                          on='Animal ID', 
                          suffixes=('_out', '_in'))

# %%
# What was the result?
combined.head()
# Out:
#   Animal ID Name_out        DateTime_out MonthYear_out Date of Birth  \
# 0   A794011    Chunk 2019-05-08 18:20:00      May 2019    2017-05-02
# 1   A776359    Gizmo 2018-07-18 16:02:00      Jul 2018    2017-07-12
# 2   A821648      NaN 2020-08-16 11:38:00      Aug 2020    2019-08-16
# 3   A720371    Moose 2016-02-13 17:59:00      Feb 2016    2015-10-08
# 4   A720371    Moose 2016-02-13 17:59:00      Feb 2016    2015-10-08
#
#   Outcome Type Outcome Subtype Animal Type_out Sex upon Outcome  \
# 0    Rto-Adopt             NaN             Cat    Neutered Male
# 1     Adoption             NaN             Dog    Neutered Male
# 2   Euthanasia             NaN           Other          Unknown
# 3     Adoption             NaN             Dog    Neutered Male
# 4     Adoption             NaN             Dog    Neutered Male
#
#   Age upon Outcome  ...             DateTime_in   MonthYear_in  \
# 0          2 years  ...  05/02/2019 04:51:00 PM       May 2019
# 1           1 year  ...  07/12/2018 12:46:00 PM      July 2018
# 2           1 year  ...  08/16/2020 10:10:00 AM    August 2020
# 3         4 months  ...  02/08/2016 11:05:00 AM  February 2016
# 4         4 months  ...  02/15/2016 10:37:00 AM  February 2016
#
#                                Found Location      Intake Type  \
# 0                                 Austin (TX)  Owner Surrender
# 1           7201 Levander Loop in Austin (TX)            Stray
# 2  Armadillo Rd And Clubway Ln in Austin (TX)         Wildlife
# 3       Dove Dr And E Stassney in Austin (TX)            Stray
# 4                                 Austin (TX)  Owner Surrender
#
#   Intake Condition Animal Type_in Sex upon Intake Age upon Intake  \
# 0           Normal            Cat   Neutered Male         2 years
# 1           Normal            Dog     Intact Male          1 year
# 2             Sick          Other         Unknown          1 year
# 3           Normal            Dog     Intact Male        4 months
# 4           Normal            Dog   Neutered Male        4 months
#
#                              Breed_in           Color_in
# 0              Domestic Shorthair Mix  Brown Tabby/White
# 1             Chihuahua Shorthair Mix        White/Brown
# 2                             Raccoon               Gray
# 3  Anatol Shepherd/Labrador Retriever               Buff
# 4  Anatol Shepherd/Labrador Retriever               Buff
#
# [5 rows x 24 columns]

# %%
combined.shape
# Out:
# (180311, 24)

# %%
intakes.shape
# Out:
# (140055, 12)

# %%
outcomes.shape
# Out:
# (139957, 13)

# %% [markdown]
# Let's discuss/explore: did that work the way we expected?
#
# -

# %%
# We might want to try something different
# Can we clean something to make a better merge?
combined = combined., keep='last')

# %%
combined.loc[combined['Animal ID'] == 'A721033']
# Out:
#       Animal ID Name_out        DateTime_out MonthYear_out Date of Birth  \
# 10455   A721033  Lil Bit 2018-05-26 15:52:00      May 2018    2015-05-20
#
#           Outcome Type Outcome Subtype Animal Type_out Sex upon Outcome  \
# 10455  Return to Owner             NaN             Dog    Neutered Male
#
#       Age upon Outcome  ...             DateTime_in   MonthYear_in  \
# 10455          3 years  ...  02/22/2018 10:28:00 AM  February 2018
#
#                            Found Location    Intake Type Intake Condition  \
# 10455  6400 Ben White Blvd in Austin (TX)  Public Assist           Normal
#
#       Animal Type_in Sex upon Intake Age upon Intake         Breed_in  \
# 10455            Dog   Neutered Male         2 years  Rat Terrier Mix
#
#                      Color_in
# 10455  Tricolor/Brown Brindle
#
# [1 rows x 24 columns]

# %%
# Try again
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124341 entries, 0 to 180310
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Animal ID               124341 non-null  object
#  1   Name_out                83370 non-null   object
#  2   DateTime_out            124341 non-null  datetime64[ns]
#  3   MonthYear_out           124341 non-null  object
#  4   Date of Birth           124341 non-null  datetime64[ns]
#  5   Outcome Type            124321 non-null  object
#  6   Outcome Subtype         60919 non-null   object
#  7   Animal Type_out         124341 non-null  object
#  8   Sex upon Outcome        124340 non-null  object
#  9   Age upon Outcome        124320 non-null  object
#  10  Breed_out               124341 non-null  object
#  11  Color_out               124341 non-null  object
#  12  Calculated Age in Days  124341 non-null  int64
#  13  Name_in                 83370 non-null   object
#  14  DateTime_in             124341 non-null  object
#  15  MonthYear_in            124341 non-null  object
#  16  Found Location          124341 non-null  object
#  17  Intake Type             124341 non-null  object
#  18  Intake Condition        124341 non-null  object
#  19  Animal Type_in          124341 non-null  object
#  20  Sex upon Intake         124340 non-null  object
#  21  Age upon Intake         124341 non-null  object
#  22  Breed_in                124341 non-null  object
#  23  Color_in                124341 non-null  object
# dtypes: datetime64[ns](2), int64(1), object(21)
# memory usage: 23.7+ MB

# %% [markdown]
# # Level Up: Quick Column Name Clean Up Code
#
# Throwing a quick use of a lambda function your way:

# %%
outcomes_renamed = outcomes.rename(columns = lambda x: x.replace(" ", "_").lower())
outcomes_renamed.head()
# Out:
#   animal_id   name            datetime monthyear date_of_birth outcome_type  \
# 0   A794011  Chunk 2019-05-08 18:20:00  May 2019    2017-05-02    Rto-Adopt
# 1   A776359  Gizmo 2018-07-18 16:02:00  Jul 2018    2017-07-12     Adoption
# 2   A821648    NaN 2020-08-16 11:38:00  Aug 2020    2019-08-16   Euthanasia
# 3   A720371  Moose 2016-02-13 17:59:00  Feb 2016    2015-10-08     Adoption
# 4   A674754    NaN 2014-03-18 11:47:00  Mar 2014    2014-03-12     Transfer
#
#   outcome_subtype animal_type sex_upon_outcome age_upon_outcome  \
# 0             NaN         Cat    Neutered Male          2 years
# 1             NaN         Dog    Neutered Male           1 year
# 2             NaN       Other          Unknown           1 year
# 3             NaN         Dog    Neutered Male         4 months
# 4         Partner         Cat      Intact Male           6 days
#
#                                 breed              color  \
# 0              Domestic Shorthair Mix  Brown Tabby/White
# 1             Chihuahua Shorthair Mix        White/Brown
# 2                             Raccoon               Gray
# 3  Anatol Shepherd/Labrador Retriever               Buff
# 4              Domestic Shorthair Mix       Orange Tabby
#
#    calculated_age_in_days
# 0                     736
# 1                     371
# 2                     366
# 3                     128
# 4                       6

# %% [markdown]
# # Level Up: `pandas.set_option()`

# %% [markdown]
# We can adjust how `pandas` works by setting options in advance.

# %% [markdown]
# For complete documentation, see [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/options.html).

# %% [markdown]
# ## Block Scientific Notation

# %% [markdown]
# For example, suppose we want to prevent numbers from being displayed in scientific notation.

# %%
df = pd.DataFrame([[1e9, 2e9], [3e9, 4e9]])
df
# Out:
#               0             1
# 0  1.000000e+09  2.000000e+09
# 1  3.000000e+09  4.000000e+09

# %% [markdown]
# Then we can use:

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

df
# Out:
#               0             1
# 0 1000000000.00 2000000000.00
# 1 3000000000.00 4000000000.00

# %% [markdown]
# ## See More Rows

# %% [markdown]
# Or suppose we want `pandas` to show more rows.

# %%
df2 = pd.DataFrame(np.array(range(100)))
df2

# %% [markdown]
# In that case we can use:

# %%
pd.set_option('display.max_rows', 100)

df2
